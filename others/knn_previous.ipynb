# %%
import os
import random
import cv2
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %%
TRAIN_DIR = 'F:/datasets/CIFAR-10-images-master/CIFAR-10-images-master/train'
CATEGORIES = []
for c in os.listdir(TRAIN_DIR):
    CATEGORIES.append(c)
print(CATEGORIES)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
TRAIN_DATA = []
for c in CATEGORIES:
    path = os.path.join(TRAIN_DIR,c)
    class_num = CATEGORIES.index(c)
    for img in tqdm(os.listdir(path)):
        img_arr = cv2.imread(os.path.join(path,img))
        TRAIN_DATA.append([img_arr, class_num])
print(len(TRAIN_DATA))
# Out:
# 100%|██████████| 5000/5000 [00:20<00:00, 242.15it/s]
# 100%|██████████| 5000/5000 [00:20<00:00, 249.53it/s]
# 100%|██████████| 5000/5000 [00:20<00:00, 242.25it/s]
# 100%|██████████| 5000/5000 [00:20<00:00, 247.65it/s]
# 100%|██████████| 5000/5000 [00:19<00:00, 253.83it/s]
# 100%|██████████| 5000/5000 [00:20<00:00, 249.22it/s]
# 100%|██████████| 5000/5000 [00:20<00:00, 245.26it/s]
# 100%|██████████| 5000/5000 [00:19<00:00, 251.18it/s]
# 100%|██████████| 5000/5000 [00:19<00:00, 250.88it/s]
# 100%|██████████| 5000/5000 [00:19<00:00, 254.73it/s]
# 50000

# %%
random.shuffle(TRAIN_DATA)
plt.figure(figsize=(20,10))

for i in range(50):
    plt.subplot(5,10,i+1)
    plt.imshow(TRAIN_DATA[i][0])
    plt.xlabel(CATEGORIES[TRAIN_DATA[i][1]])
    plt.xticks([])
    plt.yticks([])
    if i==50:
        break
plt.show()

# %%
f0 = TRAIN_DATA[0:10000]
f1 = TRAIN_DATA[10000:20000]
f2 = TRAIN_DATA[20000:30000]
f3 = TRAIN_DATA[30000:40000]
f4 = TRAIN_DATA[40000:50000]

# %%
import math 
for i in range(5):
    if i==0:
        train = f1+f2+f3+f4
        validation = f0

        scores = []
        for v in validation:
            for t in train:
                l2_dist = math.sqrt(np.sum(t**2-v**2))
                scores.append(l2_dist)
                scores.append()

            
    elif i==1:
        train = f0+f2+f3+f4
        validation = f1
    elif i==2:
        train = f1+f0+f3+f4
        validation = f2
    elif i==3:
        train = f1+f2+f0+f4
        validation = f3
    elif i==4:
        train = f1+f2+f3+f0
        validation = f4
    print(len(train), len(validation))
